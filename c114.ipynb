# %% [markdown]
# <a href="https://colab.research.google.com/github/Vedang21/C114/blob/main/c114.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
data_to_load=files.upload()
# Out:
#      <input type="file" id="files-ae8fbe9f-6820-4a88-b4cb-ba7f484b03d9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ae8fbe9f-6820-4a88-b4cb-ba7f484b03d9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving c114.csv to c114.csv

# %%
import pandas as pd
import plotly.express as px
df=pd.read_csv("c114.csv")
height=df["Height"].tolist()
weight=df["Weight"].tolist()
fig=px.scatter(x=height,y=weight)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b436e313-2d1a-43ef-b366-6040a5407768" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b436e313-2d1a-43ef-b366-6040a5407768")) {
#                     Plotly.newPlot(
#                         'b436e313-2d1a-43ef-b366-6040a5407768',
# ...

# %%
m=1
c=0
y=[]
for x in height:
  y_value=m*x+c
  y.append(y_value)
  fig=px.scatter(x=height,y=weight)
  fig.update_layout(shapes=[dict(
      type='line',
      y0=min(y),y1=max(y),
      x0=min(height),x1=max(height)
  )])
  fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1d09a121-b3ba-427b-a6ef-e6ea47243b82" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1d09a121-b3ba-427b-a6ef-e6ea47243b82")) {
#                     Plotly.newPlot(
#                         '1d09a121-b3ba-427b-a6ef-e6ea47243b82',
# ...

# %%
m=0.95
c=0.93
y=[]
for x in height:
  y_value=m*x+c
  y.append(y_value)
  fig=px.scatter(x=height,y=weight)
  fig.update_layout(shapes=[dict(
      type='line',
      y0=min(y),y1=max(y),
      x0=min(height),x1=max(height)
  )])
  fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="104caf53-70e0-44b0-bde3-92037dc0bb9d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("104caf53-70e0-44b0-bde3-92037dc0bb9d")) {
#                     Plotly.newPlot(
#                         '104caf53-70e0-44b0-bde3-92037dc0bb9d',
# ...

# %%
x=250
y=m*x+c
print(f"weight of someone with height{x} is {y}")
# Out:
# weight of someone with height250is238.43

# %%
import numpy as np
h_array=np.array(height)
w_array=np.array(weight)
m,c=np.polyfit(h_array,w_array,1)
y=[]
for x in h_array:
  y_value=m*x+c
  y.append(y_value)
fig=px.scatter(x=h_array,y=w_array)
fig.update_layout(shapes=[dict(
      type='line',
      y0=min(y),y1=max(y),
      x0=min(h_array),x1=max(h_array)
  )])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ba14196b-e147-43ec-b993-8894bc4c1a36" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ba14196b-e147-43ec-b993-8894bc4c1a36")) {
#                     Plotly.newPlot(
#                         'ba14196b-e147-43ec-b993-8894bc4c1a36',
# ...

# %%
x=250
y=m*x+c
print(f"weight of someone with height {x} is {y}")
# Out:
# weight of someone with height 250 is 144.3421091489355
